# %% [markdown]
# <a href="https://colab.research.google.com/github/Heartbeat143/Attacks-on-Affine-Cipher/blob/master/Brute_force_attacks_on_Affine_cipher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Brute-Force and Know Plain Text Attacks on Affine Cipher***
#
# Target:- To find key using Brute-Force method using Plain text.
#
#
#
# ```
#   C = [(P * a) + b] mod n        # C = Chiper text , P = Plain text, n = 26 (length of alphabets)
#   P = [(C – b) * a^(-1) ] mod n     # (a,b) two keys are used for Affine Cipher.
# ```

# %% [markdown]
# # User input and Preprocessing

# %%
alphabets = "abcdefghijklmnopqrstuvwxyz"
alpha_order = dict()
inv_alpha = dict()
for i,ch in enumerate(alphabets):
    alpha_order[ch] = i
    inv_alpha[i] = ch
  
#input for key(a,b) and Plain text
print("NOTE:- Keys should be Relative prime i.e. gcd(a,b) = 1.")   #gcd stands for greatest common divisor.
key = list(map(int, input("Enter key values a and b for key(a,b) :").split()))
plain_text = input("Enter plain text (only letters): ").lower().replace(" ", "")
# Out:
# NOTE:- Keys should be Relative prime i.e. gcd(a,b) = 1.
# Enter key values a and b for key(a,b) :5 11
# Enter plain text (only letters): Sukhdev Singh

# %% [markdown]
# # Encryption

# %%
encrypted = dict()
for char in set(plain_text):
  encrypted[char] = ''

a,b = key[0], key[1]
for ch in encrypted.keys():
  val = ( a * alpha_order[ch] + b )  % 26    # Ci = ( a * Pi + b ) mod 26
  encrypted[ch] = inv_alpha[val]

cipher_text=''
for ch in plain_text:
  if ch not in encrypted:
    cipher_text += ch
  else:
    cipher_text += encrypted[ch]

print("Plain text is  :", plain_text)
print("Cipher text is :", cipher_text)
# Out:
# Plain text is  : sukhdevsingh
# Cipher text is : xhjuafmxzypu

# %% [markdown]
# # Decryption using Brute-Force and Know Plain Text
#
# Finding Key
#
# C = [(P * a) + b] mod 26
#
# P = [(C – b) * a^(-1) ] mod 26

# %%
#To find Greatest Common Divisor using Extended Euclidean Algorithm
def gcd(a, b): 
    if a == 0 : 
        return b  
    return gcd(b%a, a) 

# To find a inverse (a^-1) in m(m=26).
def modInverse(a, m) : 
    a = a % m; 
    for x in range(1, m) : 
        if ((a * x) % m == 1) : 
            return x 
    return 1

print("Cipher text is:",cipher_text)
my_keys = []
print("Hacked Keys might be:(See at the end,found key)")
for a in range(1,26,1):
  for b in range(26):
    if gcd(a,b)==1:   #as we know only 12*26 = 312 cases are there for Relative Prime.
      temp = ''

      a_inv = modInverse(a,26)
      for ch in cipher_text:
        if ch in alphabets:
          num = (alphabets.find(ch) - b ) *  a_inv     # Pi = [(Ci – b) * a^(-1) ] mod 26
          num = num % 26
          if num < 0:
            num = num + 26
          temp = temp + alphabets[num]
        else:
          temp = temp + ch
      if temp == plain_text:  #when predicted text is same as Plain text, keys has found.
        my_keys = [a,b]
      print("key(%d,%d) ::  %s " %(a,b,temp))

print("\n Key has found:- keys(%d,%d)"% (my_keys[0],my_keys[1]))
# Out:
# Cipher text is: xhjuafmxzypu
# Hacked Keys might be:(See at the end,found key)
# key(1,0) ::  xhjuafmxzypu
# key(1,1) ::  wgitzelwyxot
# key(1,2) ::  vfhsydkvxwns
# key(1,3) ::  uegrxcjuwvmr
# key(1,4) ::  tdfqwbitvulq
# key(1,5) ::  scepvahsutkp
# key(1,6) ::  rbdouzgrtsjo
# key(1,7) ::  qacntyfqsrin
# key(1,8) ::  pzbmsxeprqhm
# key(1,9) ::  oyalrwdoqpgl
# key(1,10) ::  nxzkqvcnpofk
# key(1,11) ::  mwyjpubmonej
# key(1,12) ::  lvxiotalnmdi
# key(1,13) ::  kuwhnszkmlch
# key(1,14) ::  jtvgmryjlkbg
# key(1,15) ::  isuflqxikjaf
# key(1,16) ::  hrtekpwhjize
# key(1,17) ::  gqsdjovgihyd
# key(1,18) ::  fprcinufhgxc
# key(1,19) ::  eoqbhmtegfwb
# key(1,20) ::  dnpaglsdfeva
# key(1,21) ::  cmozfkrceduz
# key(1,22) ::  blnyejqbdcty
# key(1,23) ::  akmxdipacbsx
# key(1,24) ::  zjlwchozbarw
# key(1,25) ::  yikvbgnyazqv
# key(2,1) ::  wgitzelwyxot
# key(2,3) ::  uegrxcjuwvmr
# key(2,5) ::  scepvahsutkp
# key(2,7) ::  qacntyfqsrin
# key(2,9) ::  oyalrwdoqpgl
# key(2,11) ::  mwyjpubmonej
# key(2,13) ::  kuwhnszkmlch
# key(2,15) ::  isuflqxikjaf
# key(2,17) ::  gqsdjovgihyd
# key(2,19) ::  eoqbhmtegfwb
# key(2,21) ::  cmozfkrceduz
# key(2,23) ::  akmxdipacbsx
# key(2,25) ::  yikvbgnyazqv
# key(3,1) ::  qcuprkvqizwp
# key(3,2) ::  htlgibmhzqng
# key(3,4) ::  pbtoqjuphyvo
# key(3,5) ::  gskfhalgypmf
# key(3,7) ::  oasnpitogxun
# key(3,8) ::  frjegzkfxole
# key(3,10) ::  nzrmohsnfwtm
# key(3,11) ::  eqidfyjewnkd
# key(3,13) ::  myqlngrmevsl
# key(3,14) ::  dphcexidvmjc
# key(3,16) ::  lxpkmfqldurk
# key(3,17) ::  cogbdwhculib
# key(3,19) ::  kwojlepkctqj
# key(3,20) ::  bnfacvgbtkha
# key(3,22) ::  jvnikdojbspi
# key(3,23) ::  amezbufasjgz
# key(3,25) ::  iumhjcniaroh
# key(4,1) ::  wgitzelwyxot
# key(4,3) ::  uegrxcjuwvmr
# key(4,5) ::  scepvahsutkp
# key(4,7) ::  qacntyfqsrin
# key(4,9) ::  oyalrwdoqpgl
# key(4,11) ::  mwyjpubmonej
# key(4,13) ::  kuwhnszkmlch
# key(4,15) ::  isuflqxikjaf
# key(4,17) ::  gqsdjovgihyd
# key(4,19) ::  eoqbhmtegfwb
# key(4,21) ::  cmozfkrceduz
# key(4,23) ::  akmxdipacbsx
# key(4,25) ::  yikvbgnyazqv
# key(5,1) ::  uwmjfgxukpij
# key(5,2) ::  zbroklczpuno
# key(5,3) ::  egwtpqheuzst
# key(5,4) ::  jlbyuvmjzexy
# key(5,6) ::  tvliefwtjohi
# key(5,7) ::  yaqnjkbyotmn
# key(5,8) ::  dfvsopgdtyrs
# key(5,9) ::  ikaxtuliydwx
# key(5,11) ::  sukhdevsingh
# key(5,12) ::  xzpmijaxnslm
# key(5,13) ::  ceurnofcsxqr
# key(5,14) ::  hjzwstkhxcvw
# key(5,16) ::  rtjgcdurhmfg
# key(5,17) ::  wyolhizwmrkl
# key(5,18) ::  bdtqmnebrwpq
# key(5,19) ::  giyvrsjgwbuv
# key(5,21) ::  qsifbctqglef
# key(5,22) ::  vxnkghyvlqjk
# key(5,23) ::  acsplmdaqvop
# key(5,24) ::  fhxuqrifvatu
# key(6,1) ::  wgitzelwyxot
# key(6,5) ::  scepvahsutkp
# key(6,7) ::  qacntyfqsrin
# key(6,11) ::  mwyjpubmonej
# key(6,13) ::  kuwhnszkmlch
# key(6,17) ::  gqsdjovgihyd
# key(6,19) ::  eoqbhmtegfwb
# key(6,23) ::  akmxdipacbsx
# key(6,25) ::  yikvbgnyazqv
# key(7,1) ::  smqzlijswhcz
# key(7,2) ::  dxbkwtudhsnk
# key(7,3) ::  oimvhefosdyv
# key(7,4) ::  ztxgspqzdojg
# key(7,5) ::  keirdabkozur
# key(7,6) ::  vptcolmvzkfc
# key(7,8) ::  rlpykhirvgby
# key(7,9) ::  cwajvstcgrmj
# key(7,10) ::  nhlugdenrcxu
# key(7,11) ::  yswfropycnif
# key(7,12) ::  jdhqczajnytq
# key(7,13) ::  uosbnkluyjeb
# key(7,15) ::  qkoxjghqufax
# key(7,16) ::  bvziursbfqli
# key(7,17) ::  mgktfcdmqbwt
# key(7,18) ::  xrveqnoxbmhe
# key(7,19) ::  icgpbyzimxsp
# key(7,20) ::  tnramjktxida
# key(7,22) ::  pjnwifgptezw
# key(7,23) ::  auyhtqraepkh
# key(7,24) ::  lfjsebclpavs
# key(7,25) ::  wqudpmnwalgd
# key(8,1) ::  wgitzelwyxot
# key(8,3) ::  uegrxcjuwvmr
# key(8,5) ::  scepvahsutkp
# key(8,7) ::  qacntyfqsrin
# key(8,9) ::  oyalrwdoqpgl
# key(8,11) ::  mwyjpubmonej
# key(8,13) ::  kuwhnszkmlch
# key(8,15) ::  isuflqxikjaf
# key(8,17) ::  gqsdjovgihyd
# key(8,19) ::  eoqbhmtegfwb
# key(8,21) ::  cmozfkrceduz
# key(8,23) ::  akmxdipacbsx
# key(8,25) ::  yikvbgnyazqv
# key(9,1) ::  osyfxmhourqf
# key(9,2) ::  lpvcujelronc
# key(9,4) ::  fjpwodyflihw
# key(9,5) ::  cgmtlavcifet
# key(9,7) ::  wagnfupwczyn
# key(9,8) ::  txdkcrmtzwvk
# key(9,10) ::  nrxewlgntqpe
# key(9,11) ::  koubtidkqnmb
# key(9,13) ::  eiovncxekhgv
# key(9,14) ::  bflskzubheds
# key(9,16) ::  vzfmetovbyxm
# key(9,17) ::  swcjbqlsyvuj
# key(9,19) ::  mqwdvkfmspod
# key(9,20) ::  jntashcjpmla
# key(9,22) ::  dhnumbwdjgfu
# key(9,23) ::  aekrjytagdcr
# key(9,25) ::  uyeldsnuaxwl
# key(10,1) ::  wgitzelwyxot
# key(10,3) ::  uegrxcjuwvmr
# key(10,7) ::  qacntyfqsrin
# key(10,9) ::  oyalrwdoqpgl
# key(10,11) ::  mwyjpubmonej
# key(10,13) ::  kuwhnszkmlch
# key(10,17) ::  gqsdjovgihyd
# key(10,19) ::  eoqbhmtegfwb
# key(10,21) ::  cmozfkrceduz
# key(10,23) ::  akmxdipacbsx
# key(11,1) ::  ckwxhybcovgx
# key(11,2) ::  jrdeofijvcne
# key(11,3) ::  qyklvmpqcjul
# key(11,4) ::  xfrsctwxjqbs
# key(11,5) ::  emyzjadeqxiz
# key(11,6) ::  ltfgqhklxepg
# key(11,7) ::  samnxorselwn
# key(11,8) ::  zhtuevyzlsdu
# key(11,9) ::  goablcfgszkb
# key(11,10) ::  nvhisjmnzgri
# key(11,12) ::  bjvwgxabnufw
# key(11,13) ::  iqcdnehiubmd
# key(11,14) ::  pxjkulopbitk
# key(11,15) ::  weqrbsvwipar
# key(11,16) ::  dlxyizcdpwhy
# key(11,17) ::  ksefpgjkwdof
# key(11,18) ::  rzlmwnqrdkvm
# key(11,19) ::  ygstduxykrct
# key(11,20) ::  fnzakbefryja
# key(11,21) ::  mughrilmyfqh
# key(11,23) ::  aiuvfwzamtev
# key(11,24) ::  hpbcmdghtalc
# key(11,25) ::  owijtknoahsj
# key(12,1) ::  wgitzelwyxot
# key(12,5) ::  scepvahsutkp
# key(12,7) ::  qacntyfqsrin
# key(12,11) ::  mwyjpubmonej
# key(12,13) ::  kuwhnszkmlch
# key(12,17) ::  gqsdjovgihyd
# key(12,19) ::  eoqbhmtegfwb
# key(12,23) ::  akmxdipacbsx
# key(12,25) ::  yikvbgnyazqv
# key(13,1) ::  wgitzelwyxot
# key(13,2) ::  vfhsydkvxwns
# key(13,3) ::  uegrxcjuwvmr
# key(13,4) ::  tdfqwbitvulq
# key(13,5) ::  scepvahsutkp
# key(13,6) ::  rbdouzgrtsjo
# key(13,7) ::  qacntyfqsrin
# key(13,8) ::  pzbmsxeprqhm
# key(13,9) ::  oyalrwdoqpgl
# key(13,10) ::  nxzkqvcnpofk
# key(13,11) ::  mwyjpubmonej
# key(13,12) ::  lvxiotalnmdi
# key(13,14) ::  jtvgmryjlkbg
# key(13,15) ::  isuflqxikjaf
# key(13,16) ::  hrtekpwhjize
# key(13,17) ::  gqsdjovgihyd
# key(13,18) ::  fprcinufhgxc
# key(13,19) ::  eoqbhmtegfwb
# key(13,20) ::  dnpaglsdfeva
# key(13,21) ::  cmozfkrceduz
# key(13,22) ::  blnyejqbdcty
# key(13,23) ::  akmxdipacbsx
# key(13,24) ::  zjlwchozbarw
# key(13,25) ::  yikvbgnyazqv
# key(14,1) ::  wgitzelwyxot
# key(14,3) ::  uegrxcjuwvmr
# key(14,5) ::  scepvahsutkp
# key(14,9) ::  oyalrwdoqpgl
# key(14,11) ::  mwyjpubmonej
# key(14,13) ::  kuwhnszkmlch
# key(14,15) ::  isuflqxikjaf
# key(14,17) ::  gqsdjovgihyd
# key(14,19) ::  eoqbhmtegfwb
# key(14,23) ::  akmxdipacbsx
# key(14,25) ::  yikvbgnyazqv
# key(15,1) ::  yqedtczymfud
# key(15,2) ::  rjxwmvsrfynw
# key(15,4) ::  dvjiyhedrkzi
# key(15,7) ::  iaondmjiwpen
# key(15,8) ::  bthgwfcbpixg
# key(15,11) ::  gymlbkhguncl
# key(15,13) ::  skyxnwtsgzox
# key(15,14) ::  ldrqgpmlzshq
# key(15,16) ::  xpdcsbyxletc
# key(15,17) ::  qiwvlurqexmv
# key(15,19) ::  cuihxgdcqjyh
# key(15,22) ::  hznmclihvodm
# key(15,23) ::  asgfvebaohwf
# key(16,1) ::  wgitzelwyxot
# key(16,3) ::  uegrxcjuwvmr
# key(16,5) ::  scepvahsutkp
# key(16,7) ::  qacntyfqsrin
# key(16,9) ::  oyalrwdoqpgl
# key(16,11) ::  mwyjpubmonej
# key(16,13) ::  kuwhnszkmlch
# key(16,15) ::  isuflqxikjaf
# key(16,17) ::  gqsdjovgihyd
# key(16,19) ::  eoqbhmtegfwb
# key(16,21) ::  cmozfkrceduz
# key(16,23) ::  akmxdipacbsx
# key(16,25) ::  yikvbgnyazqv
# key(17,1) ::  micvdotmgjkv
# key(17,2) ::  plfygrwpjmny
# key(17,3) ::  soibjuzsmpqb
# key(17,4) ::  vrlemxcvpste
# key(17,5) ::  yuohpafysvwh
# key(17,6) ::  bxrksdibvyzk
# key(17,7) ::  eaunvgleybcn
# key(17,8) ::  hdxqyjohbefq
# key(17,9) ::  kgatbmrkehit
# key(17,10) ::  njdwepunhklw
# key(17,11) ::  qmgzhsxqknoz
# key(17,12) ::  tpjckvatnqrc
# key(17,13) ::  wsmfnydwqtuf
# key(17,14) ::  zvpiqbgztwxi
# key(17,15) ::  cysltejcwzal
# key(17,16) ::  fbvowhmfzcdo
# key(17,18) ::  lhbucnslfiju
# key(17,19) ::  okexfqvoilmx
# key(17,20) ::  rnhaityrlopa
# key(17,21) ::  uqkdlwbuorsd
# key(17,22) ::  xtngozexruvg
# key(17,23) ::  awqjrchauxyj
# key(17,24) ::  dztmufkdxabm
# key(17,25) ::  gcwpxingadep
# key(18,1) ::  wgitzelwyxot
# key(18,5) ::  scepvahsutkp
# key(18,7) ::  qacntyfqsrin
# key(18,11) ::  mwyjpubmonej
# key(18,13) ::  kuwhnszkmlch
# key(18,17) ::  gqsdjovgihyd
# key(18,19) ::  eoqbhmtegfwb
# key(18,23) ::  akmxdipacbsx
# key(18,25) ::  yikvbgnyazqv
# key(19,1) ::  iokbpsrietyb
# key(19,2) ::  xdzqehgxtinq
# key(19,3) ::  msoftwvmixcf
# key(19,4) ::  bhduilkbxmru
# key(19,5) ::  qwsjxazqmbgj
# key(19,6) ::  flhympofbqvy
# key(19,7) ::  uawnbeduqfkn
# key(19,8) ::  jplcqtsjfuzc
# key(19,9) ::  yearfihyujor
# key(19,10) ::  ntpguxwnjydg
# key(19,11) ::  cievjmlcynsv
# key(19,12) ::  rxtkybarnchk
# key(19,13) ::  gmiznqpgcrwz
# key(19,14) ::  vbxocfevrglo
# key(19,15) ::  kqmdrutkgvad
# key(19,16) ::  zfbsgjizvkps
# key(19,17) ::  ouqhvyxokzeh
# key(19,18) ::  djfwknmdzotw
# key(19,20) ::  hnjaorqhdsxa
# key(19,21) ::  wcypdgfwshmp
# key(19,22) ::  lrnesvulhwbe
# key(19,23) ::  agcthkjawlqt
# key(19,24) ::  pvriwzyplafi
# key(19,25) ::  ekgxloneapux
# key(20,1) ::  wgitzelwyxot
# key(20,3) ::  uegrxcjuwvmr
# key(20,7) ::  qacntyfqsrin
# key(20,9) ::  oyalrwdoqpgl
# key(20,11) ::  mwyjpubmonej
# key(20,13) ::  kuwhnszkmlch
# key(20,17) ::  gqsdjovgihyd
# key(20,19) ::  eoqbhmtegfwb
# key(20,21) ::  cmozfkrceduz
# key(20,23) ::  akmxdipacbsx
# key(21,1) ::  georvudgqlsr
# key(21,2) ::  bzjmqpyblgnm
# key(21,4) ::  rpzcgforbwdc
# key(21,5) ::  mkuxbajmwryx
# key(21,8) ::  xvfimluxhcji
# key(21,10) ::  nlvycbknxszy
# key(21,11) ::  igqtxwfisnut
# key(21,13) ::  ywgjnmvyidkj
# key(21,16) ::  jhruyxgjtovu
# key(21,17) ::  ecmptsbeojqp
# key(21,19) ::  uscfjiruezgf
# key(21,20) ::  pnxaedmpzuba
# key(21,22) ::  fdnqutcfpkrq
# key(21,23) ::  ayilpoxakfml
# key(21,25) ::  qoybfenqavcb
# key(22,1) ::  wgitzelwyxot
# key(22,3) ::  uegrxcjuwvmr
# key(22,5) ::  scepvahsutkp
# key(22,7) ::  qacntyfqsrin
# key(22,9) ::  oyalrwdoqpgl
# key(22,13) ::  kuwhnszkmlch
# key(22,15) ::  isuflqxikjaf
# key(22,17) ::  gqsdjovgihyd
# key(22,19) ::  eoqbhmtegfwb
# key(22,21) ::  cmozfkrceduz
# key(22,23) ::  akmxdipacbsx
# key(22,25) ::  yikvbgnyazqv
# key(23,1) ::  kygljqfksbel
# key(23,2) ::  thpuszotbknu
# key(23,3) ::  cqydbixcktwd
# key(23,4) ::  lzhmkrgltcfm
# key(23,5) ::  uiqvtapuclov
# key(23,6) ::  drzecjydluxe
# key(23,7) ::  mainlshmudgn
# key(23,8) ::  vjrwubqvdmpw
# key(23,9) ::  esafdkzemvyf
# key(23,10) ::  nbjomtinveho
# key(23,11) ::  wksxvcrwenqx
# key(23,12) ::  ftbgelafnwzg
# key(23,13) ::  ockpnujowfip
# key(23,14) ::  xltywdsxfory
# key(23,15) ::  guchfmbgoxah
# key(23,16) ::  pdlqovkpxgjq
# key(23,17) ::  ymuzxetygpsz
# key(23,18) ::  hvdignchpybi
# key(23,19) ::  qemrpwlqyhkr
# key(23,20) ::  znvayfuzhqta
# key(23,21) ::  iwejhodiqzcj
# key(23,22) ::  rfnsqxmrzils
# key(23,24) ::  jxfkipejradk
# key(23,25) ::  sgotrynsajmt
# key(24,1) ::  wgitzelwyxot
# key(24,5) ::  scepvahsutkp
# key(24,7) ::  qacntyfqsrin
# key(24,11) ::  mwyjpubmonej
# key(24,13) ::  kuwhnszkmlch
# key(24,17) ::  gqsdjovgihyd
# key(24,19) ::  eoqbhmtegfwb
# key(24,23) ::  akmxdipacbsx
# key(24,25) ::  yikvbgnyazqv
# key(25,1) ::  eushbwpecdmh
# key(25,2) ::  fvticxqfdeni
# key(25,3) ::  gwujdyrgefoj
# key(25,4) ::  hxvkezshfgpk
# key(25,6) ::  jzxmgbujhirm
# key(25,7) ::  kaynhcvkijsn
# key(25,8) ::  lbzoidwljkto
# key(25,9) ::  mcapjexmklup
# key(25,11) ::  oecrlgzomnwr
# key(25,12) ::  pfdsmhapnoxs
# key(25,13) ::  qgetnibqopyt
# key(25,14) ::  rhfuojcrpqzu
# key(25,16) ::  tjhwqletrsbw
# key(25,17) ::  ukixrmfustcx
# key(25,18) ::  vljysngvtudy
# key(25,19) ::  wmkztohwuvez
# key(25,21) ::  yombvqjywxgb
# key(25,22) ::  zpncwrkzxyhc
# key(25,23) ::  aqodxslayzid
# key(25,24) ::  brpeytmbzaje
#
#  Key has found:- keys(5,11)
